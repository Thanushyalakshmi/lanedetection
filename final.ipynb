# %%
# !unzip "/content/drive/MyDrive/Accident.yolov8.zip"

# %%
# !pip install ultralytics -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 721.0/721.0 kB 10.1 MB/s eta 0:00:00

# %%
from ultralytics import YOLO
# Out:
# C:\Users\user\AppData\Roaming\Python\Python38\site-packages\transformers\utils\generic.py:441: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   _torch_pytree._register_pytree_node(

# %%
model = YOLO("yolov8m.pt")
# Out:
# ...
# 100%|█████████████████████████████████████████████████████████████████████████████| 49.7M/49.7M [00:04<00:00, 11.0MB/s]

# %%
model.train(data = r"F:\ABDUL\LANE detetion\data.yaml", epochs = 1)
# Out:
# New https://pypi.org/project/ultralytics/8.1.47 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.34 🚀 Python-3.8.0 torch-2.2.1+cpu CPU (Intel Core(TM) i9-14900K)
# ...

# %%
infer = YOLO(r"F:\ABDUL\LANE detetion\web\LANEm.pt")

# %%
infer.predict(r"F:\ABDUL\LANE detetion\web\TEST.MP4" , save=True, save_txt=True)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/889) F:\ABDUL\LANE detetion\web\TEST.MP4: 384x640 1 Middle Lane, 2 Right Lanes, 97.7ms
# video 1/1 (frame 2/889) F:\ABDUL\LANE detetion\web\TEST.MP4: 384x640 1 Middle Lane, 2 Right Lanes, 83.7ms
# video 1/1 (frame 3/889) F:\ABDUL\LANE detetion\web\TEST.MP4: 384x640 1 Middle Lane, 2 Right Lanes, 81.7ms
# video 1/1 (frame 4/889) F:\ABDUL\LANE detetion\web\TEST.MP4: 384x640 1 Middle Lane, 2 Right Lanes, 81.7ms
# ...
